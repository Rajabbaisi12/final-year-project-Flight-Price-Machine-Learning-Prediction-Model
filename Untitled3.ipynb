# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()

# %%
data = pd.read_csv("C:/Users/R/Desktop/YEAR 3 NOTES/SEM 1/FINAL YEAR PROJECT/practicals/archive/flight data.csv")

# %%
data.head()
# Out:
#      s from_country dest_airport_code dest_country
# 0  GRU       Brazil               MUC      Germany  \
# 1  GRU       Brazil               MUC      Germany
# 2  GRU       Brazil               MUC      Germany
# 3  GRU       Brazil               MUC      Germany
# 4  GRU       Brazil               MUC      Germany
#
#                          aircraft_type airline_number         airline_name
# 0               Boeing 787|Airbus A320          multi   [LATAM| Lufthansa]  \
# 1  Airbus A330|Airbus A321|Airbus A320          multi  [Iberia| Lufthansa]
# 2                Boeing 787|Boeing 787             AC         [Air Canada]
# 3               Boeing 787|Airbus A350          multi  [United| Lufthansa]
# 4           Airbus A350|Airbus A320neo             BA    [British Airways]
#
#           flight_number   departure_time     arrival_time  duration  stops
# 0           LA702|LA702  7/28/2022 23:00  7/30/2022 08:15      1695      1  \
# ...

# %%
x = data[['from_airport_code', 'from_country', 'dest_airport_code' , 'dest_country', 'aircraft_type', 'airline_number', 'airline_name', 'flight_number', 'departure_time', 'arrival_time', 'duration', 'stops', 'co2_emissions', 'avg_co2_emission_for_this_route', 'co2_percentage', 'scan_date'
]]

y = data['price']

# %%
x
# Out:
#        from_airport_code from_country dest_airport_code dest_country
# 0                    ALG      Algeria               AEP    Argentina  \
# 1                    ALG      Algeria               AEP    Argentina
# 2                    ALG      Algeria               AEP    Argentina
# 3                    ALG      Algeria               AEP    Argentina
# 4                    ALG      Algeria               AEP    Argentina
# ...                  ...          ...               ...          ...
# 998861               BOM        India               SYD    Australia
# 998862               BOM        India               SYD    Australia
# 998863               BOM        India               SYD    Australia
# 998864               BOM        India               SYD    Australia
# 998865               BOM        India               SYD    Australia
#
#                                             aircraft_type airline_number
# ...

# %%
y
# Out:
# 0         1279.0
# 1         1279.0
# 2         1284.0
# 3         1290.0
# 4         1347.0
#            ...
# 998861    1317.0
# 998862    1317.0
# 998863    1328.0
# 998864    1368.0
# 998865    1368.0
# Name: price, Length: 998866, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
#separating data into test and train data
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2)

# %%
x_test
# Out:
#        from_airport_code from_country dest_airport_code          dest_country
# 170905               VIE      Austria               PHX         United States  \
# 717129               ADD     Ethiopia               CAI                 Egypt
# 639738               DUB       Dublin               DXB  United Arab Emirates
# 738155               CDG       France               DUB                Dublin
# 615442               DUB       Dublin               CPH               Denmark
# ...                  ...          ...               ...                   ...
# 323076               YYZ       Canada               ATH                Greece
# 748332               CDG       France               KUL              Malaysia
# 886653               MUC      Germany               FLL         United States
# 501536               PVG        China               MIA         United States
# 556768               CPH      Denmark               YYZ                Canada
#
# ...

# %%
x_train
# Out:
#        from_airport_code from_country dest_airport_code   dest_country
# 997003               DEL        India               ZRH         Zurich  \
# 936504               DEL        India               BOM          India
# 842731               MUC      Germany               DUB         Dublin
# 995252               DEL        India               FLL  United States
# 168388               VIE      Austria               PHX  United States
# ...                  ...          ...               ...            ...
# 969107               DEL        India               ARN         Sweden
# 966712               DEL        India               FRA        Germany
# 416009               CTU        China               LAX  United States
# 361554               SCL        Chile               AEP      Argentina
# 327400               YYZ       Canada               BKK       Thailand
#
#                               aircraft_type airline_number
# ...

# %%
y_train
# Out:
# 997003    4060.0
# 936504     168.0
# 842731     245.0
# 995252    1864.0
# 168388    3477.0
#            ...
# 969107    2432.0
# 966712     742.0
# 416009    3375.0
# 361554     825.0
# 327400    3468.0
# Name: price, Length: 799092, dtype: float64

# %%
data.shape
# Out:
# (998866, 18)

# %%
#data cleaning or removing empty cells 
data.dropna(inplace = True)

# %%
data.shape
# Out:
# (892539, 18)

# %%
#checking for empty cells
data.isnull().sum()
# Out:
# from_airport_code                  0
# from_country                       0
# dest_airport_code                  0
# dest_country                       0
# aircraft_type                      0
# airline_number                     0
# airline_name                       0
# flight_number                      0
# departure_time                     0
# arrival_time                       0
# duration                           0
# stops                              0
# price                              0
# currency                           0
# co2_emissions                      0
# avg_co2_emission_for_this_route    0
# co2_percentage                     0
# scan_date                          0
# dtype: int64

# %%
x_train.shape
# Out:
# (799092, 16)

# %%
#data cleaning or removing empty cells 
x_train.dropna(inplace = True)

# %%
#checking for empty cells
x_train.isnull().sum()
# Out:
# from_airport_code                  0
# from_country                       0
# dest_airport_code                  0
# dest_country                       0
# aircraft_type                      0
# airline_number                     0
# airline_name                       0
# flight_number                      0
# departure_time                     0
# arrival_time                       0
# duration                           0
# stops                              0
# co2_emissions                      0
# avg_co2_emission_for_this_route    0
# co2_percentage                     0
# scan_date                          0
# dtype: int64

# %%
x_train.shape
# Out:
# (714299, 16)

# %%
#Separating the scan_date column into date and time
x_train['scan_date']
x_train['scan_date'] = pd.to_datetime(x_train['scan_date'])

# %%
x_train['Sdate'] = x_train['scan_date'].dt.date
x_train['Stime'] = x_train['scan_date'].dt.time

# %%
#spliting SCAN time.
x_train['Shours'] = x_train['scan_date'].dt.hour
x_train['Sminutes'] = x_train['scan_date'].dt.minute
x_train['Sseconds'] = x_train['scan_date'].dt.second

# %%
#droping the scan date
x_train.drop(["scan_date"], axis = 1, inplace = True)

# %%
x_train['scan_day'] = pd.to_datetime(x_train.Sdate, format ="%d/%m/%y").dt.day

# %%
x_train['scan_month'] = pd.to_datetime(x_train.Sdate, format ="%d/%m/%y").dt.month

# %%
#droping the sdate
x_train.drop(["Sdate"], axis = 1, inplace = True)

# %%
#droping the stime
x_train.drop(["Stime"], axis = 1, inplace = True)

# %%
#separating departure column into date and time
x_train['departure_time']
x_train['departure_time'] = pd.to_datetime(x_train['departure_time'])

# %%
x_train['Ddate'] = x_train['departure_time'].dt.date
x_train['Dtime'] = x_train['departure_time'].dt.time

# %%
x_train['Dhours'] = x_train['departure_time'].dt.hour
x_train['Dminutes'] = x_train['departure_time'].dt.minute
x_train['Dseconds'] = x_train['departure_time'].dt.second

# %%
x_train['departure_day'] = pd.to_datetime(x_train.Ddate, format ="%d/%m/%y").dt.day

# %%
x_train['departure_month'] = pd.to_datetime(x_train.Ddate, format ="%d/%m/%y").dt.month

# %%
x_train.drop(["Ddate"], axis = 1, inplace = True)

# %%
x_train.drop(["Dtime"], axis = 1, inplace = True)

# %%
x_train.drop(["departure_time"], axis = 1, inplace = True)

# %%
#separating the arrival column into date and time.
x_train['arrival_time']
x_train['arrival_time'] = pd.to_datetime(x_train['arrival_time'])

# %%
x_train['Rdate'] = x_train['arrival_time'].dt.date
x_train['Rtime'] = x_train['arrival_time'].dt.time

# %%
x_train.drop(["arrival_time"], axis = 1, inplace = True)

# %%
x_train['arrival_day'] = pd.to_datetime(x_train.Rdate, format ="%d/%m/%y").dt.day

# %%
x_train['arrival_month'] = pd.to_datetime(x_train.Rdate, format ="%d/%m/%y").dt.month

# %%
x_train.drop(["Rdate"], axis = 1, inplace = True)

# %%
x_train.drop(["Rtime"], axis = 1, inplace = True)

# %%
#splitting arrival time
x_train['Ahours'] = x_train['arrival_time'].dt.hour
x_train['Aminutes'] = x_train['arrival_time'].dt.minute
x_train['Aseconds'] = x_train['arrival_time'].dt.second

# %%
x_train["airline_name"].value_counts()
# Out:
# airline_name
# [Lufthansa]                                46681
# [United]                                   20542
# [American]                                 17235
# [British Airways]                          14226
# [KLM]                                      14047
#                                            ...
# [MEA| Etihad| Air Arabia]                      1
# [Brussels Airlines| SWISS| Korean Air]         1
# [Air France| Aer Lingus| JetBlue]              1
# [LATAM| El Al| EgyptAir]                       1
# [LATAM| Gol| SWISS| Singapore Airlines]        1
# Name: count, Length: 7307, dtype: int64

# %%
#airline vs price
sns.catplot(y = "price", x = "airline_name", data = data.sort_values("price", ascending = False), kind = "boxen", height = 6 , aspect = 3)

plt.show()

# %%
aircraft_type  = data[["aircraft_type"]]
aircraft_type = pd.get_dummies(aircraft_type, drop_first = True)
aircraft_type.head()

# %%
x_train["from_country"].value_counts()
# Out:
# from_country
# Germany      84397
# Australia    68861
# Brazil       57717
# China        54819
# India        46969
# Canada       43322
# Denmark      41099
# France       40262
# Belgium      38053
# Dublin       36699
# Greece       36348
# Austria      36301
# Egypt        32852
# Columbia     31913
# Chile        26930
# Argentina    16280
# Ethiopia     12091
# Algeria       9386
# Name: count, dtype: int64

# %%
#from_country vs price
sns.catplot(y = "price", x = "from_country", data = data.sort_values("price", ascending = False), kind = "boxen", height = 6 , aspect = 3)

plt.show()

# %%
#changing categorical data into onehotencoding
from_country  = x_train[["from_country"]]
from_country = pd.get_dummies(from_country, drop_first = True)
from_country.head()
# Out:
#         from_country_Argentina  from_country_Australia  from_country_Austria
# 997003                   False                   False                 False  \
# 936504                   False                   False                 False
# 842731                   False                   False                 False
# 995252                   False                   False                 False
# 168388                   False                   False                  True
#
#         from_country_Belgium  from_country_Brazil  from_country_Canada
# 997003                 False                False                False  \
# 936504                 False                False                False
# 842731                 False                False                False
# 995252                 False                False                False
# 168388                 False                False                False
#
#         from_country_Chile  from_country_China  from_country_Columbia
# ...

# %%
x_train["dest_country"].value_counts()
# Out:
# dest_country
# United States           157291
# United Kingdom           38394
# India                    34546
# Germany                  27401
# Australia                24559
# Brazil                   24177
# Japan                    18110
# Canada                   15047
# South Africa             14801
# Italy                    14321
# Zurich                   13265
# France                   13149
# Rome                     12965
# Mexico                   12641
# Denmark                  12356
# Netherlands              12274
# Dublin                   12269
# Austria                  12263
# Spain                    12261
# Belgium                  12208
# Turkey                   11885
# Portugal                 11771
# Sweden                   11664
# Thailand                 11104
# Norway                   11001
# Greece                   10819
# Columbia                 10600
# Singapore                10308
# Egypt                    10154
# ...

# %%
dest_country  = x_train[["dest_country"]]
dest_country = pd.get_dummies(dest_country, drop_first = True)
dest_country.head()
# Out:
#         dest_country_Argentina  dest_country_Australia  dest_country_Austria
# 997003                   False                   False                 False  \
# 936504                   False                   False                 False
# 842731                   False                   False                 False
# 995252                   False                   False                 False
# 168388                   False                   False                 False
#
#         dest_country_Belgium  dest_country_Brazil  dest_country_Canada
# 997003                 False                False                False  \
# 936504                 False                False                False
# 842731                 False                False                False
# 995252                 False                False                False
# 168388                 False                False                False
#
#         dest_country_Chile  dest_country_China  dest_country_Columbia
# ...

# %%
data.drop(["from_airport_code", "dest_airport_code"], axis = 1, inplace = True)

# %%
x_train["stops"].value_counts()
# Out:
# stops
# 2    368714
# 1    290090
# 3     42964
# 0     10444
# 4      1909
# 5       167
# 6        11
# Name: count, dtype: int64

# %%
x_train.replace({ "0 stop": 0, "1 stop": 1,"2 stop": 2, "3 stop": 3, "4 stop":4, "5 stop": 5, "6 stop": 6 }, inplace = True)

# %%
from_country  = x_train[["from_country"]]
from_country = pd.get_dummies(from_country, drop_first = True)
from_country.head()
# Out:
#         from_country_Argentina  from_country_Australia  from_country_Austria
# 997003                   False                   False                 False  \
# 936504                   False                   False                 False
# 842731                   False                   False                 False
# 995252                   False                   False                 False
# 168388                   False                   False                  True
#
#         from_country_Belgium  from_country_Brazil  from_country_Canada
# 997003                 False                False                False  \
# 936504                 False                False                False
# 842731                 False                False                False
# 995252                 False                False                False
# 168388                 False                False                False
#
#         from_country_Chile  from_country_China  from_country_Columbia
# ...

# %%
from_airport_code  = x_train[["from_airport_code"]]
from_airport_code = pd.get_dummies(from_airport_code, drop_first = True)
from_airport_code.head()

# %%
dest_airport_code  = x_train[["dest_airport_code"]]
dest_airport_code = pd.get_dummies(dest_airport_code, drop_first = True)
dest_airport_code.head()

# %%
dest_country  = x_train[["dest_country"]]
dest_country = pd.get_dummies(dest_country, drop_first = True)
dest_country.head()
# Out:
#         dest_country_Argentina  dest_country_Australia  dest_country_Austria
# 997003                   False                   False                 False  \
# 936504                   False                   False                 False
# 842731                   False                   False                 False
# 995252                   False                   False                 False
# 168388                   False                   False                 False
#
#         dest_country_Belgium  dest_country_Brazil  dest_country_Canada
# 997003                 False                False                False  \
# 936504                 False                False                False
# 842731                 False                False                False
# 995252                 False                False                False
# 168388                 False                False                False
#
#         dest_country_Chile  dest_country_China  dest_country_Columbia
# ...

# %%
airline_number  = x_train[["airline_number "]]
airline_number  = pd.get_dummies(airline_number , drop_first = True)
airline_number .head()

# %%
airline_name  = x_train[["airline_name"]]
airline_name = pd.get_dummies(airline_name, drop_first = True)
airline_name.head()

# %%
flight_number  = x_train[["flight_number"]]
flight_number = pd.get_dummies(flight_number, drop_first = True)
flight_number.head()

# %%
aircraft_type  = x_train[["aircraft_type"]]
aircraft_type = pd.get_dummies(aircraft_type, drop_first = True)
aircraft_type.head()

# %%
x_train.drop(["from_airport_code", "dest_airport_code", "airline_number", "flight_number", "aircraft_type"], axis = 1, inplace = True)

# %%
x_train.drop(["co2_emissions", "avg_co2_emission_for_this_route", "co2_percentage"], axis = 1, inplace = True)

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming your DataFrame is called 'data' and the airline name column is 'airline_name'
airline_encoder = LabelEncoder()
x_train['airline_name_encoded'] = airline_encoder.fit_transform(x_train['airline_name'])

# %%
airline_name  = x_train[["airline_name"]]
airline_name = pd.get_dummies(airline_name, drop_first = True)
airline_name.head()

# %%
airline_name_encoded  = x_train[["airline_name_encoded"]]
airline_name_encoded = pd.get_dummies(airline_name_encoded, drop_first = True)
airline_name_encoded.head()
# Out:
#         airline_name_encoded
# 997003                  3684
# 936504                  1035
# 842731                  2128
# 995252                  7036
# 168388                  5145

# %%
train_x = pd.concat([x_train, from_country, dest_country, airline_name_encoded], axis = 1)

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming your DataFrame is called 'data' and the aircraft name column is 'aircraft_name'
aircraft_type_encoder = LabelEncoder()
x_train['aircraft_type_encoded'] = aircraft_type_encoder.fit_transform(x_train['aircraft_type'])

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming your DataFrame is called 'data' and the aircraft name column is 'aircraft_name'
airline_number_encoder = LabelEncoder()
x_train['airline_number_encoded'] = airline_number_encoder.fit_transform(x_train['airline_number'])

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming your DataFrame is called 'data' and the aircraft name column is 'aircraft_name'
dest_airport_code_encoder = LabelEncoder()
x_train['dest_airport_code_encoded'] = dest_airport_code_encoder.fit_transform(x_train['dest_airport_code'])

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming your DataFrame is called 'data' and the aircraft name column is 'aircraft_name'

from_airport_code_encoder = LabelEncoder()
x_train['from_airport_code_encoded'] = from_airport_code_encoder.fit_transform(x_train['from_airport_code'])

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming your DataFrame is called 'data' and the aircraft name column is 'aircraft_name'

flight_number_encoder = LabelEncoder()
x_train['flight_number_encoded'] = flight_number_encoder.fit_transform(x_train['flight_number'])

# %%
train_x.drop(["from_country", "dest_country", "airline_name"], axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[395], line 1
# ----> 1 train_x.drop(["from_country", "dest_country", "airline_name"], axis = 1, inplace = True)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5268, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5120 def drop(
#    5121     self,
#    5122     labels: IndexLabel = None,
#    (...)
#    5129     errors: IgnoreRaise = "raise",
#    5130 ) -> DataFrame | None:
#    5131     """
#    5132     Drop specified labels from rows or columns.
#    5133
#    (...)
#    5266             weight  1.0     0.8
#    5267     """
# -> 5268     return super().drop(
#    5269         labels=labels,
#    5270         axis=axis,
#    5271         index=index,
#    5272         columns=columns,
#    5273         level=level,
# ...

# %%
train_x.drop(["airline_name_encoded"], axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[396], line 1
# ----> 1 train_x.drop(["airline_name_encoded"], axis = 1, inplace = True)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5268, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5120 def drop(
#    5121     self,
#    5122     labels: IndexLabel = None,
#    (...)
#    5129     errors: IgnoreRaise = "raise",
#    5130 ) -> DataFrame | None:
#    5131     """
#    5132     Drop specified labels from rows or columns.
#    5133
#    (...)
#    5266             weight  1.0     0.8
#    5267     """
# -> 5268     return super().drop(
#    5269         labels=labels,
#    5270         axis=axis,
#    5271         index=index,
#    5272         columns=columns,
#    5273         level=level,
#    5274         inplace=inplace,
# ...

# %%
train_x.drop(["co2_emissions", "avg_co2_emission_for_this_route", "co2_percentage"], axis = 1, inplace = True)

# %%
train_x.drop(["from_airport_code", "dest_airport_code", "aircraft_type", "airline_number","flight_number"], axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[397], line 1
# ----> 1 train_x.drop(["from_airport_code", "dest_airport_code", "aircraft_type", "airline_number","flight_number"], axis = 1, inplace = True)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5268, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5120 def drop(
#    5121     self,
#    5122     labels: IndexLabel = None,
#    (...)
#    5129     errors: IgnoreRaise = "raise",
#    5130 ) -> DataFrame | None:
#    5131     """
#    5132     Drop specified labels from rows or columns.
#    5133
#    (...)
#    5266             weight  1.0     0.8
#    5267     """
# -> 5268     return super().drop(
#    5269         labels=labels,
#    5270         axis=axis,
#    5271         index=index,
#    5272         columns=columns,
# ...

# %%
train_x.head()
# Out:
#         duration  stops  Shours  Sminutes  Sseconds  scan_day  scan_month
# 647589      1070      2      17        52        59        29           4  \
# 684963      1435      2      17        52        59        29           4
# 658785      1040      1      17        52        59        29           4
# 644013       915      1      17        52        59        29           4
# 536628      1730      1      17        52        59        29           4
#
#         Dhours  Dminutes  Dseconds  ...  dest_country_Spain
# 647589       5        55         0  ...               False  \
# 684963      16        35         0  ...               False
# 658785      17        45         0  ...               False
# 644013       8        50         0  ...               False
# 536628      23        35         0  ...               False
#
#         dest_country_Sweden  dest_country_Taiwan  dest_country_Thailand
# 647589                False                False                  False  \
# ...

# %%
train_x.shape
# Out:
# (714344, 80)

# %%
#test data

# %%
x_test.head()
# Out:
#        from_airport_code from_country dest_airport_code          dest_country
# 170905               VIE      Austria               PHX         United States  \
# 717129               ADD     Ethiopia               CAI                 Egypt
# 639738               DUB       Dublin               DXB  United Arab Emirates
# 738155               CDG       France               DUB                Dublin
# 615442               DUB       Dublin               CPH               Denmark
#
#                                 aircraft_type airline_number
# 170905      Boeing 777|Boeing 737|Airbus A320          multi  \
# 717129     Airbus A330|Airbus A330|Boeing 777             SV
# 639738                                    NaN             0B
# 738155                Airbus A320|Embraer 190             BA
# 615442  Airbus A321|Airbus A220-300 Passenger             AF
#
#               airline_name      flight_number       departure_time
# ...

# %%
x_test.shape
# Out:
# (199774, 16)

# %%
#data cleaning or removing empty cells 
x_test.dropna(inplace = True)

# %%
#checking for empty cells
x_test.isnull().sum()
# Out:
# from_airport_code                  0
# from_country                       0
# dest_airport_code                  0
# dest_country                       0
# aircraft_type                      0
# airline_number                     0
# airline_name                       0
# flight_number                      0
# departure_time                     0
# arrival_time                       0
# duration                           0
# stops                              0
# co2_emissions                      0
# avg_co2_emission_for_this_route    0
# co2_percentage                     0
# scan_date                          0
# dtype: int64

# %%
x_test.shape
# Out:
# (178700, 16)

# %%
#Separating the scan_date column into date and time
x_test['scan_date']
x_test['scan_date'] = pd.to_datetime(x_test['scan_date'])

# %%
x_test['Sdate'] = x_test['scan_date'].dt.date
x_test['Stime'] = x_test['scan_date'].dt.time

# %%
#spliting SCAN time.
x_test['Shours'] = x_test['scan_date'].dt.hour
x_test['Sminutes'] = x_test['scan_date'].dt.minute
x_test['Sseconds'] = x_test['scan_date'].dt.second

# %%
#droping the scan date
x_test.drop(["scan_date"], axis = 1, inplace = True)

# %%
x_test['scan_day'] = pd.to_datetime(x_test.Sdate, format ="%d/%m/%y").dt.day

# %%
x_test['scan_month'] = pd.to_datetime(x_test.Sdate, format ="%d/%m/%y").dt.month

# %%
#droping the sdate
x_test.drop(["Sdate"], axis = 1, inplace = True)

# %%
#droping the stime
x_test.drop(["Stime"], axis = 1, inplace = True)

# %%
#separating departure column into date and time
x_test['departure_time']
x_test['departure_time'] = pd.to_datetime(x_test['departure_time'])

# %%
x_test['Ddate'] = x_test['departure_time'].dt.date
x_test['Dtime'] = x_test['departure_time'].dt.time

# %%
x_test['Dhours'] = x_test['departure_time'].dt.hour
x_test['Dminutes'] = x_test['departure_time'].dt.minute
x_test['Dseconds'] = x_test['departure_time'].dt.second

# %%
x_test['departure_day'] = pd.to_datetime(x_test.Ddate, format ="%d/%m/%y").dt.day

# %%
x_test['departure_month'] = pd.to_datetime(x_test.Ddate, format ="%d/%m/%y").dt.month

# %%
x_test.drop(["Ddate"], axis = 1, inplace = True)

# %%
x_test.drop(["Dtime"], axis = 1, inplace = True)

# %%
x_test.drop(["departure_time"], axis = 1, inplace = True)

# %%
#separating the arrival column into date and time.
x_test['arrival_time']
x_test['arrival_time'] = pd.to_datetime(x_test['arrival_time'])

# %%
x_test['Rdate'] = x_test['arrival_time'].dt.date
x_test['Rtime'] = x_test['arrival_time'].dt.time

# %%
x_test['arrival_day'] = pd.to_datetime(x_test.Rdate, format ="%d/%m/%y").dt.day

# %%
x_test['arrival_month'] = pd.to_datetime(x_test.Rdate, format ="%d/%m/%y").dt.month

# %%
x_test.drop(["Rdate"], axis = 1, inplace = True)

# %%
x_test.drop(["Rtime"], axis = 1, inplace = True)

# %%
#splitting arrival time
x_test['Ahours'] = x_test['arrival_time'].dt.hour
x_test['Aminutes'] = x_test['arrival_time'].dt.minute
x_test['Aseconds'] = x_test['arrival_time'].dt.second

# %%
x_test.drop(["arrival_time"], axis = 1, inplace = True)

# %%
x_test["airline_name"].value_counts()
# Out:
# airline_name
# [Lufthansa]                                            11562
# [United]                                                4988
# [American]                                              4345
# [British Airways]                                       3568
# [Turkish Airlines]                                      3566
#                                                        ...
# [EgyptAir| Etihad| British Airways]                        1
# [Austrian| Lufthansa| Korean Air]                          1
# [Lufthansa| SAS| Air Canada]                               1
# [Singapore Airlines| Cathay Pacific| China Eastern]        1
# [Ethiopian| Austrian| Croatia]                             1
# Name: count, Length: 5140, dtype: int64

# %%
x_test["from_country"].value_counts()
# Out:
# from_country
# Germany      21142
# Australia    17207
# Brazil       14264
# China        13959
# India        11781
# Canada       10622
# Denmark      10336
# France       10011
# Belgium       9511
# Austria       9263
# Greece        9087
# Dublin        9069
# Egypt         8280
# Columbia      7928
# Chile         6704
# Argentina     4088
# Ethiopia      3061
# Algeria       2387
# Name: count, dtype: int64

# %%
#changing categorical data into onehotencoding
from_country  = x_test[["from_country"]]
from_country = pd.get_dummies(from_country, drop_first = True)
from_country.head()
# Out:
#         from_country_Argentina  from_country_Australia  from_country_Austria
# 170905                   False                   False                  True  \
# 717129                   False                   False                 False
# 738155                   False                   False                 False
# 615442                   False                   False                 False
# 241815                   False                   False                 False
#
#         from_country_Belgium  from_country_Brazil  from_country_Canada
# 170905                 False                False                False  \
# 717129                 False                False                False
# 738155                 False                False                False
# 615442                 False                False                False
# 241815                 False                 True                False
#
#         from_country_Chile  from_country_China  from_country_Columbia
# ...

# %%
x_test["dest_country"].value_counts()
# Out:
# dest_country
# United States           39460
# United Kingdom           9690
# India                    8644
# Germany                  6657
# Australia                6222
# Brazil                   6084
# Japan                    4387
# South Africa             3782
# Canada                   3676
# Italy                    3563
# France                   3370
# Zurich                   3355
# Rome                     3245
# Denmark                  3119
# Mexico                   3118
# Austria                  3107
# Dublin                   3099
# Spain                    3070
# Netherlands              2992
# Belgium                  2953
# Turkey                   2916
# Portugal                 2910
# Greece                   2832
# Sweden                   2807
# Thailand                 2761
# Columbia                 2698
# Norway                   2653
# Singapore                2631
# Egypt                    2577
# Peru                     2467
# ...

# %%
dest_country  = x_test[["dest_country"]]
dest_country = pd.get_dummies(dest_country, drop_first = True)
dest_country.head()
# Out:
#         dest_country_Argentina  dest_country_Australia  dest_country_Austria
# 170905                   False                   False                 False  \
# 717129                   False                   False                 False
# 738155                   False                   False                 False
# 615442                   False                   False                 False
# 241815                   False                   False                 False
#
#         dest_country_Belgium  dest_country_Brazil  dest_country_Canada
# 170905                 False                False                False  \
# 717129                 False                False                False
# 738155                 False                False                False
# 615442                 False                False                False
# 241815                 False                False                False
#
#         dest_country_Chile  dest_country_China  dest_country_Columbia
# ...

# %%
x_test.drop(["from_airport_code", "dest_airport_code"], axis = 1, inplace = True)

# %%
x_test.drop([ "airline_number", "flight_number", "aircraft_type"], axis = 1, inplace = True)

# %%
x_test.drop(["co2_emissions", "avg_co2_emission_for_this_route", "co2_percentage"], axis = 1, inplace = True)

# %%
x_test.drop(["airline_name_encoded"], axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[438], line 1
# ----> 1 x_test.drop(["airline_name_encoded"], axis = 1, inplace = True)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5268, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5120 def drop(
#    5121     self,
#    5122     labels: IndexLabel = None,
#    (...)
#    5129     errors: IgnoreRaise = "raise",
#    5130 ) -> DataFrame | None:
#    5131     """
#    5132     Drop specified labels from rows or columns.
#    5133
#    (...)
#    5266             weight  1.0     0.8
#    5267     """
# -> 5268     return super().drop(
#    5269         labels=labels,
#    5270         axis=axis,
#    5271         index=index,
#    5272         columns=columns,
#    5273         level=level,
#    5274         inplace=inplace,
# ...

# %%
x_test["stops"].value_counts()
# Out:
# stops
# 2    91985
# 1    73056
# 3    10796
# 0     2536
# 4      485
# 5       48
# 6        2
# Name: count, dtype: int64

# %%
x_test.replace({ "0 stop": 0, "1 stop": 1,"2 stop": 2, "3 stop": 3, "4 stop":4, "5 stop": 5, "6 stop": 6 }, inplace = True)

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming your DataFrame is called 'x_test' and the airline name column is 'airline_name'
airline_encoder = LabelEncoder()
x_test['airline_name_encoded'] = airline_encoder.fit_transform(x_test['airline_name'])

# %%
airline_name_encoded  = x_test[["airline_name_encoded"]]
airline_name_encoded = pd.get_dummies(airline_name_encoded, drop_first = True)
airline_name_encoded.head()
# Out:
#         airline_name_encoded
# 552958                  3562
# 791036                   860
# 263079                  2814
# 892870                   677
# 544011                  1703

# %%
test_x = pd.concat([x_test, from_country, dest_country, airline_name_encoded], axis = 1)

# %%
test_x.drop(["from_country", "dest_country", "airline_name"], axis = 1, inplace = True)

# %%
test_x.drop(["airline_name_encoded"], axis = 1, inplace = True)

# %%
train_x.drop(["co2_emissions", "avg_co2_emission_for_this_route", "co2_percentage"], axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[444], line 1
# ----> 1 train_x.drop(["co2_emissions", "avg_co2_emission_for_this_route", "co2_percentage"], axis = 1, inplace = True)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5268, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5120 def drop(
#    5121     self,
#    5122     labels: IndexLabel = None,
#    (...)
#    5129     errors: IgnoreRaise = "raise",
#    5130 ) -> DataFrame | None:
#    5131     """
#    5132     Drop specified labels from rows or columns.
#    5133
#    (...)
#    5266             weight  1.0     0.8
#    5267     """
# -> 5268     return super().drop(
#    5269         labels=labels,
#    5270         axis=axis,
#    5271         index=index,
#    5272         columns=columns,
#    5273         level=level,
# ...

# %%
train_x.drop(["from_airport_code", "dest_airport_code", "aircraft_type", "airline_number","flight_number"], axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[445], line 1
# ----> 1 train_x.drop(["from_airport_code", "dest_airport_code", "aircraft_type", "airline_number","flight_number"], axis = 1, inplace = True)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5268, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5120 def drop(
#    5121     self,
#    5122     labels: IndexLabel = None,
#    (...)
#    5129     errors: IgnoreRaise = "raise",
#    5130 ) -> DataFrame | None:
#    5131     """
#    5132     Drop specified labels from rows or columns.
#    5133
#    (...)
#    5266             weight  1.0     0.8
#    5267     """
# -> 5268     return super().drop(
#    5269         labels=labels,
#    5270         axis=axis,
#    5271         index=index,
#    5272         columns=columns,
# ...

# %%
test_x.head()
# Out:
#         duration  stops  Shours  Sminutes  Sseconds  scan_day  scan_month
# 170905    1136.0    2.0    17.0      52.0      59.0      29.0         4.0  \
# 717129     965.0    2.0    17.0      52.0      59.0      29.0         4.0
# 738155     535.0    1.0    17.0      52.0      59.0      29.0         4.0
# 615442     945.0    1.0    17.0      52.0      59.0      29.0         4.0
# 241815    1805.0    1.0    17.0      52.0      59.0      29.0         4.0
#
#         Dhours  Dminutes  Dseconds  ...  dest_country_Spain
# 170905    10.0      30.0       0.0  ...               False  \
# 717129     3.0      20.0       0.0  ...               False
# 738155     7.0       5.0       0.0  ...               False
# 615442     6.0       5.0       0.0  ...               False
# 241815     1.0      25.0       0.0  ...               False
#
#         dest_country_Sweden  dest_country_Taiwan  dest_country_Thailand
# 170905                False                False                  False  \
# ...

# %%
test_x.shape
# Out:
# (892999, 80)

# %%
#FEATURE ENGINERING

# %%
train_x.columns
# Out:
# Index(['duration', 'stops', 'Shours', 'Sminutes', 'Sseconds', 'scan_day',
#        'scan_month', 'Dhours', 'Dminutes', 'Dseconds', 'departure_day',
#        'departure_month', 'arrival_day', 'arrival_month', 'Ahours', 'Aminutes',
#        'Aseconds', 'from_country_Argentina', 'from_country_Australia',
#        'from_country_Austria', 'from_country_Belgium', 'from_country_Brazil',
#        'from_country_Canada', 'from_country_Chile', 'from_country_China',
#        'from_country_Columbia', 'from_country_Denmark', 'from_country_Dublin',
#        'from_country_Egypt', 'from_country_Ethiopia', 'from_country_France',
#        'from_country_Germany', 'from_country_Greece', 'from_country_India',
#        'dest_country_Argentina', 'dest_country_Australia',
#        'dest_country_Austria', 'dest_country_Belgium', 'dest_country_Brazil',
#        'dest_country_Canada', 'dest_country_Chile', 'dest_country_China',
#        'dest_country_Columbia', 'dest_country_Denmark', 'dest_country_Dublin',
# ...

# %%
X = train_x.loc[:, ['duration', 'stops', 'Shours', 'Sminutes', 'Sseconds', 'scan_day',
       'scan_month', 'Dhours', 'Dminutes', 'Dseconds', 'departure_day',
       'departure_month', 'arrival_day', 'arrival_month', 'Ahours', 'Aminutes',
       'Aseconds', 'from_country_Argentina', 'from_country_Australia',
       'from_country_Austria', 'from_country_Belgium', 'from_country_Brazil',
       'from_country_Canada', 'from_country_Chile', 'from_country_China',
       'from_country_Columbia', 'from_country_Denmark', 'from_country_Dublin',
       'from_country_Egypt', 'from_country_Ethiopia', 'from_country_France',
       'from_country_Germany', 'from_country_Greece', 'from_country_India',
       'dest_country_Argentina', 'dest_country_Australia',
       'dest_country_Austria', 'dest_country_Belgium', 'dest_country_Brazil',
       'dest_country_Canada', 'dest_country_Chile', 'dest_country_China',
       'dest_country_Columbia', 'dest_country_Denmark', 'dest_country_Dublin',
       'dest_country_Egypt', 'dest_country_Ethiopia', 'dest_country_France',
       'dest_country_Germany', 'dest_country_Greece', 'dest_country_India',
       'dest_country_Indonesia', 'dest_country_Italy', 'dest_country_Japan',
       'dest_country_Kenya', 'dest_country_Malaysia', 'dest_country_Mexico',
       'dest_country_Morocco', 'dest_country_Netherlands',
       'dest_country_Norway', 'dest_country_Panama', 'dest_country_Peru',
       'dest_country_Philippines', 'dest_country_Portugal',
       'dest_country_Qatar', 'dest_country_Rome', 'dest_country_Russia',
       'dest_country_Singapore', 'dest_country_South Africa',
       'dest_country_South Korea', 'dest_country_Spain', 'dest_country_Sweden',
       'dest_country_Taiwan', 'dest_country_Thailand', 'dest_country_Turkey',
       'dest_country_United Arab Emirates', 'dest_country_United Kingdom',
       'dest_country_United States', 'dest_country_Vietnam',
       'dest_country_Zurich'] ] 
X.head()
# Out:
#         duration  stops  Shours  Sminutes  Sseconds  scan_day  scan_month
# 647589      1070      2      17        52        59        29           4  \
# 684963      1435      2      17        52        59        29           4
# 658785      1040      1      17        52        59        29           4
# 644013       915      1      17        52        59        29           4
# 536628      1730      1      17        52        59        29           4
#
#         Dhours  Dminutes  Dseconds  ...  dest_country_Spain
# 647589       5        55         0  ...               False  \
# 684963      16        35         0  ...               False
# 658785      17        45         0  ...               False
# 644013       8        50         0  ...               False
# 536628      23        35         0  ...               False
#
#         dest_country_Sweden  dest_country_Taiwan  dest_country_Thailand
# 647589                False                False                  False  \
# ...

# %%
y = train_x.iloc[:, 1]
y.head()
# Out:
# 647589    2
# 684963    2
# 658785    1
# 644013    1
# 536628    1
# Name: stops, dtype: int64

# %%
y_train
# Out:
# 548903    4022.0
# 119045    1363.0
# 76675     1561.0
# 12969     1483.0
# 341803     547.0
#            ...
# 182395     692.0
# 588532     635.0
# 373922     601.0
# 395672    1038.0
# 323489     954.0
# Name: price, Length: 799092, dtype: float64

# %%
#finds correlation between independent and dependent Attributes.

plt.figure(figsize = (18,18))
sns.heatmap(train_x.corr(), annot =True, cmap = "RdYlGn")
plt.show()

# %%
#important feature using ExtraTreesRegressor

# %%
from sklearn.ensemble import ExtraTreesRegressor
selection = ExtraTreesRegressor()
selection.fit(X, y)
# Out:
# ExtraTreesRegressor()

# %%
sns.relplot(x = 'price', y = 'airline_name', data=data)

# %%
#plot graph of important features
plt.figure(figsize = (12,8))
feat_importances = pd.Series(selection.feature_importances_, index = X.columns)
feat_importances.nlargest(20).plot(kind = 'barh')
plt.show()

# %%
ExtraTreesRegressor()
# Out:
# ExtraTreesRegressor()

# %%
y
# Out:
# 647589    2
# 684963    2
# 658785    1
# 644013    1
# 536628    1
#          ..
# 350909    1
# 784926    1
# 162628    2
# 569591    2
# 728557    0
# Name: stops, Length: 714344, dtype: int64

# %%
#random forest

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_statement)
# Out:
#   Cell In[289], line 2
#     X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_statement)
#                                                                                                ^
# SyntaxError: positional argument follows keyword argument

# %%
from sklearn.ensemble import RandomForestRegressor
reg_rf = RandomForestRegressor()
reg_rf.fit(train_x, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[459], line 3
#       1 from sklearn.ensemble import RandomForestRegressor
#       2 reg_rf = RandomForestRegressor()
# ----> 3 reg_rf.fit(train_x, y_train)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\ensemble\_forest.py:345, in BaseForest.fit(self, X, y, sample_weight)
#     343 if issparse(y):
#     344     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 345 X, y = self._validate_data(
#     346     X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     347 )
#     348 if sample_weight is not None:
#     349     sample_weight = _check_sample_weight(sample_weight, X)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:584, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
# ...

# %%
x_train.head()
# Out:
#        from_country   dest_country              airline_name  duration  stops
# 997003        India         Zurich                [Emirates]      1140      1  \
# 936504        India          India               [Air India]      1115      1
# 842731      Germany         Dublin         [British Airways]       585      1
# 995252        India  United States  [Virgin Atlantic| Delta]      1757      2
# 168388      Austria  United States             [LOT| United]      3414      2
#
#         Shours  Sminutes  Sseconds  scan_day  scan_month  ...  Dminutes
# 997003      17        52        59        29           4  ...        50  \
# 936504      17        52        59        29           4  ...         0
# 842731      17        52        59        29           4  ...        15
# 995252      17        52        59        29           4  ...        30
# 168388      17        52        59        29           4  ...        25
#
# ...

# %%
y_train.head()
# Out:
# 997003    4060.0
# 936504     168.0
# 842731     245.0
# 995252    1864.0
# 168388    3477.0
# Name: price, dtype: float64

# %%
#data cleaning or removing empty cells 
y_train.dropna(inplace = True)

# %%
#checking for empty cells
y_train.isnull().sum()
# Out:
# 0

# %%
y_train_new = y_train[np.isfinite(y_train).all(1)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     513             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     514         except KeyError:
# --> 515             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8288\2699079582.py in ?()
# ----> 1 y_train_new = y_train[np.isfinite(y_train).all(1)]
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, axis, bool_only, skipna, **kwargs)
#   11352             bool_only=None,
#   11353             skipna: bool_t = True,
#   11354             **kwargs,
# ...
