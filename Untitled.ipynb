# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()

# %%
data = pd.read_csv("C:/Users/R/Desktop/YEAR 3 NOTES/SEM 1/FINAL YEAR PROJECT/practicals/archive/flight data.csv")

# %%
data.head()
# Out:
#   airline_number                flight_number       departure_time
# 0          multi  AF1491|AF1491|AF1491|AF1491  2022-04-30 14:30:00  \
# 1          multi  AF1491|AF1491|AF1491|AF1491  2022-04-30 14:30:00
# 2          multi  AF1855|AF1855|AF1855|AF1855  2022-04-30 12:45:00
# 3          multi  AF1491|AF1491|AF1491|AF1491  2022-04-30 14:30:00
# 4          multi         LH1317|LH1317|LH1317  2022-04-30 12:35:00
#
#           arrival_time  duration  stops   price currency  co2_emissions
# 0  2022-05-01 10:15:00      1425      3  1279.0      USD      1320000.0  \
# 1  2022-05-01 10:15:00      1425      3  1279.0      USD      1195000.0
# 2  2022-05-01 10:15:00      1530      3  1284.0      USD      1248000.0
# 3  2022-05-01 10:15:00      1425      3  1290.0      USD      1347000.0
# 4  2022-05-01 10:15:00      1540      2  1347.0      USD      1381000.0
#
#    avg_co2_emission_for_this_route co2_percentage  Shours  Sminutes  Sseconds
# ...

# %%
x = data[['from_airport_code', 'from_country', 'dest_airport_code' , 'dest_country', 'aircraft_type', 'airline_number', 'airline_name', 'flight_number', 'departure_time', 'arrival_time', 'duration', 'stops', 'co2_emissions', 'avg_co2_emission_for_this_route', 'co2_percentage', 'scan_date'
]]

y = data['price']

# %%
x
# Out:
#        from_airport_code from_country dest_airport_code dest_country
# 0                    ALG      Algeria               AEP    Argentina  \
# 1                    ALG      Algeria               AEP    Argentina
# 2                    ALG      Algeria               AEP    Argentina
# 3                    ALG      Algeria               AEP    Argentina
# 4                    ALG      Algeria               AEP    Argentina
# ...                  ...          ...               ...          ...
# 998861               BOM        India               SYD    Australia
# 998862               BOM        India               SYD    Australia
# 998863               BOM        India               SYD    Australia
# 998864               BOM        India               SYD    Australia
# 998865               BOM        India               SYD    Australia
#
#                                             aircraft_type airline_number
# ...

# %%
y
# Out:
# 0         1279.0
# 1         1279.0
# 2         1284.0
# 3         1290.0
# 4         1347.0
#            ...
# 998861    1317.0
# 998862    1317.0
# 998863    1328.0
# 998864    1368.0
# 998865    1368.0
# Name: price, Length: 998866, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2)

# %%
x_test
# Out:
#        from_airport_code from_country dest_airport_code          dest_country
# 579982               CPH      Denmark               BRU               Belgium  \
# 781856               FRA      Germany               CNF                Brazil
# 456872               SHA        China               HND                 Japan
# 315725               YYZ       Canada               CPH               Denmark
# 970117               BOM        India               GRU                Brazil
# ...                  ...          ...               ...                   ...
# 471128               XIY        China               LAX         United States
# 209429               BRU      Belgium               DOH                 Qatar
# 414240               CTU        China               SYD             Australia
# 751102               CDG       France               DXB  United Arab Emirates
# 255655               CNF       Brazil               MEL             Australia
#
# ...

# %%
data.shape
# Out:
# (998866, 18)

# %%
#cleaaning and removing empty cells
data.dropna(inplace = True)

# %%
data.isnull().sum()
# Out:
# from_airport_code                  0
# from_country                       0
# dest_airport_code                  0
# dest_country                       0
# aircraft_type                      0
# airline_number                     0
# airline_name                       0
# flight_number                      0
# departure_time                     0
# arrival_time                       0
# duration                           0
# stops                              0
# price                              0
# currency                           0
# co2_emissions                      0
# avg_co2_emission_for_this_route    0
# co2_percentage                     0
# scan_date                          0
# dtype: int64

# %%
data.shape
# Out:
# (892539, 18)

# %%
#Separating the scan_date column into date and time
data['scan_date']
data['scan_date'] = pd.to_datetime(data['scan_date'])

# %%
data['Sdate'] = data['scan_date'].dt.date
data['Stime'] = data['scan_date'].dt.time

# %%
#spliting SCAN time.
data['scan_date']
data['scan_date'] = pd.to_datetime(data['scan_date'])

# %%
data['Shours'] = data['scan_date'].dt.hour
data['Sminutes'] = data['scan_date'].dt.minute
data['Sseconds'] = data['scan_date'].dt.second

# %%
data.drop(["scan_date"], axis = 1, inplace = True)

# %%
data['scan_day'] = pd.to_datetime(data.Sdate, format ="%d/%m/%y").dt.day

# %%
data['scan_month'] = pd.to_datetime(data.Sdate, format ="%d/%m/%y").dt.month

# %%
data.drop(["Sdate"], axis = 1, inplace = True)

# %%
data.drop(["Stime"], axis = 1, inplace = True)

# %%
#separating departure column into date and time
data['departure_time']
data['departure_time'] = pd.to_datetime(data['departure_time'])

# %%
data['Ddate'] = data['departure_time'].dt.date
data['Dtime'] = data['departure_time'].dt.time

# %%
data.drop(["departure_time"], axis = 1, inplace = True)

# %%
#spliting departure time.
data['departure_time']
data['departure_time'] = pd.to_datetime(data['departure_time'])

# %%
data['Dhours'] = data['departure_time'].dt.hour
data['Dminutes'] = data['departure_time'].dt.minute
data['Dseconds'] = data['departure_time'].dt.second

# %%
data['departure_day'] = pd.to_datetime(data.Ddate, format ="%d/%m/%y").dt.day

# %%
data['departure_month'] = pd.to_datetime(data.Ddate, format ="%d/%m/%y").dt.month

# %%
data.drop(["Ddate"], axis = 1, inplace = True)

# %%
data.drop(["Dtime"], axis = 1, inplace = True)

# %%
data.drop(["departure_time"], axis = 1, inplace = True)

# %%
#separating the arrival column into date and time.
data['arrival_time']
data['arrival_time'] = pd.to_datetime(data['arrival_time'])

# %%
data['Rdate'] = data['arrival_time'].dt.date
data['Rtime'] = data['arrival_time'].dt.time

# %%
data.drop(["arrival_time"], axis = 1, inplace = True)

# %%
data['arrival_day'] = pd.to_datetime(data.Rdate, format ="%d/%m/%y").dt.day

# %%
data['arrival_month'] = pd.to_datetime(data.Rdate, format ="%d/%m/%y").dt.month

# %%
data.drop(["Rdate"], axis = 1, inplace = True)

# %%
data.drop(["Rtime"], axis = 1, inplace = True)

# %%
data.drop(["arrival_time"], axis = 1, inplace = True)

# %%
#spliting arrival time.
data['arrival_time']
data['arrival_time'] = pd.to_datetime(data['arrival_time'])

# %%
data['Ahours'] = data['arrival_time'].dt.hour
data['Aminutes'] = data['arrival_time'].dt.minute
data['Aseconds'] = data['arrival_time'].dt.second

# %%
data["airline_name"].value_counts()
# Out:
# airline_name
# [Lufthansa]                             58243
# [United]                                25530
# [American]                              21580
# [British Airways]                       17794
# [Turkish Airlines]                      17559
#                                         ...
# [Shenzhen| THAI]                            1
# [XiamenAir| Air China| ANA]                 1
# [Shenzhen| ANA| Hawaiian]                   1
# [EgyptAir| Garuda Indonesia]                1
# [Brussels Airlines| LATAM| Paranair]        1
# Name: count, Length: 7590, dtype: int64

# %%
#airline vs price
sns.catplot(y = "price", x = "airline_name", data = data.sort_values("price", ascending = False), kind = "boxen", height = 6 , aspect = 3)

plt.show()

# %%
aircraft_type  = data[["aircraft_type"]]
aircraft_type = pd.get_dummies(aircraft_type, drop_first = True)
aircraft_type.head()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[23], line 2
#       1 aircraft_type  = data[["aircraft_type"]]
# ----> 2 aircraft_type = pd.get_dummies(aircraft_type, drop_first = True)
#       3 aircraft_type.head()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\encoding.py:203, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     199     with_dummies = [data.select_dtypes(exclude=dtypes_to_encode)]
#     201 for col, pre, sep in zip(data_to_encode.items(), prefix, prefix_sep):
#     202     # col is (column_name, column), use just column data here
# --> 203     dummy = _get_dummies_1d(
#     204         col[1],
#     205         prefix=pre,
#     206         prefix_sep=sep,
#     207         dummy_na=dummy_na,
#     208         sparse=sparse,
#     209         drop_first=drop_first,
# ...

# %%
data["from_country"].value_counts()
# Out:
# from_country
# China        125384
# Germany      108820
# Australia     91727
# Brazil        75979
# India         62566
# Canada        55056
# Denmark       53745
# France        52340
# Belgium       48776
# Dublin        48634
# Austria       48284
# Greece        48084
# Columbia      43324
# Egypt         42330
# Chile         37025
# Argentina     21483
# Ethiopia      19572
# Algeria       15737
# Name: count, dtype: int64

# %%
#from_country vs price
sns.catplot(y = "price", x = "from_country", data = data.sort_values("price", ascending = False), kind = "boxen", height = 6 , aspect = 3)

plt.show()

# %%
from_country  = data[["from_country"]]
from_country = pd.get_dummies(from_country, drop_first = True)
from_country.head()
# Out:
#    from_country_Argentina  from_country_Australia  from_country_Austria
# 0                   False                   False                 False  \
# 1                   False                   False                 False
# 2                   False                   False                 False
# 3                   False                   False                 False
# 4                   False                   False                 False
#
#    from_country_Belgium  from_country_Brazil  from_country_Canada
# 0                 False                False                False  \
# 1                 False                False                False
# 2                 False                False                False
# 3                 False                False                False
# 4                 False                False                False
#
#    from_country_Chile  from_country_China  from_country_Columbia
# 0               False               False                  False  \
# ...

# %%
data["dest_country"].value_counts()
# Out:
# dest_country
# United States           207877
# United Kingdom           50792
# India                    49830
# Germany                  36296
# Brazil                   33443
# Australia                33374
# China                    25723
# Japan                    24095
# South Africa             19994
# Canada                   19260
# Italy                    19210
# Rome                     17905
# Mexico                   17656
# Zurich                   17424
# France                   17342
# Spain                    16710
# Portugal                 16630
# Belgium                  16501
# Denmark                  16487
# Netherlands              16324
# Austria                  16193
# Dublin                   16177
# Sweden                   15621
# Thailand                 15575
# Turkey                   15403
# Norway                   14806
# Singapore                14793
# Greece                   14625
# Columbia                 14255
# ...

# %%
dest_country  = data[["dest_country"]]
dest_country = pd.get_dummies(dest_country, drop_first = True)
dest_country.head()
# Out:
#    dest_country_Argentina  dest_country_Australia  dest_country_Austria
# 0                    True                   False                 False  \
# 1                    True                   False                 False
# 2                    True                   False                 False
# 3                    True                   False                 False
# 4                    True                   False                 False
#
#    dest_country_Belgium  dest_country_Brazil  dest_country_Canada
# 0                 False                False                False  \
# 1                 False                False                False
# 2                 False                False                False
# 3                 False                False                False
# 4                 False                False                False
#
#    dest_country_Chile  dest_country_China  dest_country_Columbia
# 0               False               False                  False  \
# ...

# %%
data.drop(["from_airport_code", "dest_airport_code"], axis = 1, inplace = True)

# %%
data["stops"].value_counts()
# Out:
# stops
# 2    515960
# 1    391153
# 3     71782
# 0     16381
# 4      3333
# 5       244
# 6        13
# Name: count, dtype: int64

# %%
data = pd.concat([data, from_country, dest_country, aircraft_type, airline_name], axis = 1)

# %%
data.drop(["from_country", "dest_country", "aircraft_type", "airline_name"], axis = 1, inplace = True)

# %%
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 x
#
# NameError: name 'x' is not defined

# %%
x_train
# Out:
#        from_airport_code from_country dest_airport_code    dest_country
# 817660               FRA      Germany               NRT           Japan  \
# 64542                SYD    Australia               MAD           Spain
# 818883               FRA      Germany               LHR  United Kingdom
# 88971                MEL    Australia               BRU         Belgium
# 287631               CNF       Brazil               FLL   United States
# ...                  ...          ...               ...             ...
# 351521               YYZ       Canada               PHX   United States
# 827855               FRA      Germany               FCO            Rome
# 649510               DUB       Dublin               IST          Turkey
# 624801               CPH      Denmark               FLL   United States
# 814033               FRA      Germany               IAH   United States
#
#                                 aircraft_type airline_number
# ...
