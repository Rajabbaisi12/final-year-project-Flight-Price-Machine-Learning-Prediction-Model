# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()

# %%
data = pd.read_csv("C:\Users\R\Desktop\YEAR 3 NOTES\SEM 1\FINAL YEAR PROJECT\practicals\archive\flight data.csv")

# %%
data = pd.read_csv("C:/Users/R/Desktop/YEAR 3 NOTES/SEM 1/FINAL YEAR PROJECT/practicals/archive/flight data.csv")

# %%
data.head()
# Out:
#   from_airport_code from_country dest_airport_code dest_country
# 0               ALG      Algeria               AEP    Argentina  \
# 1               ALG      Algeria               AEP    Argentina
# 2               ALG      Algeria               AEP    Argentina
# 3               ALG      Algeria               AEP    Argentina
# 4               ALG      Algeria               AEP    Argentina
#
#                                        aircraft_type airline_number
# 0  Airbus A318|Canadair RJ 1000|Airbus A330|Airbu...          multi  \
# 1  Airbus A318|Canadair RJ 1000|Boeing 787|Airbus...          multi
# 2     Airbus A320|Airbus A321|Boeing 787|Airbus A320          multi
# 3     Airbus A318|Airbus A320|Boeing 787|Airbus A320          multi
# 4              Airbus A321neo|Boeing 777|Airbus A320          multi
#
#                   airline_name                flight_number
# 0  [Air France| Iberia| LATAM]  AF1491|AF1491|AF1491|AF1491  \
# ...

# %%
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2)
#
# NameError: name 'x' is not defined

# %%
x = data[['from_airport_code', 'from_country', 'dest_airport_code' , 'dest_country', 'aircraft_type', 'airline_number', 'airline_name', 'flight_number', 'departure_time', 'arrival_time', 'duration', 'stops', 'co2_emissions', 'avg_co2_emission_for_this_route', 'co2_percentage', 'scan_date'
]]

y = data["price", 'currency']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('price', 'currency')
#
# The above exception was the direct cause of the following exception:
# ...

# %%
x
# Out:
#        from_airport_code from_country dest_airport_code dest_country
# 0                    ALG      Algeria               AEP    Argentina  \
# 1                    ALG      Algeria               AEP    Argentina
# 2                    ALG      Algeria               AEP    Argentina
# 3                    ALG      Algeria               AEP    Argentina
# 4                    ALG      Algeria               AEP    Argentina
# ...                  ...          ...               ...          ...
# 998861               BOM        India               SYD    Australia
# 998862               BOM        India               SYD    Australia
# 998863               BOM        India               SYD    Australia
# 998864               BOM        India               SYD    Australia
# 998865               BOM        India               SYD    Australia
#
#                                             aircraft_type airline_number
# ...

# %%
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 y
#
# NameError: name 'y' is not defined

# %%
data.y[]
# Out:
#   Cell In[11], line 1
#     data.y[]
#            ^
# SyntaxError: invalid syntax

# %%
data.describe()
# Out:
#             duration          stops          price  co2_emissions
# count  998866.000000  998866.000000  997513.000000   9.939980e+05  \
# mean     1468.213762       1.654926    1763.370116   1.111010e+06
# std       705.799677       0.652485    1985.988209   9.876891e+05
# min        55.000000       0.000000       9.000000   4.300000e+04
# 25%       973.000000       1.000000     621.000000   5.220000e+05
# 50%      1410.000000       2.000000    1189.000000   9.560000e+05
# 75%      1880.000000       2.000000    2127.000000   1.367000e+06
# max      6095.000000       6.000000   33750.000000   1.404400e+07
#
#        avg_co2_emission_for_this_route
# count                     9.104640e+05
# mean                      8.626045e+05
# std                       5.228906e+05
# min                       5.300000e+04
# 25%                       4.100000e+05
# 50%                       8.760000e+05
# 75%                       1.184000e+06
# max                       2.408000e+06

# %%
y = data['price']

# %%
data.y
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3560\10249213.py in ?()
# ----> 1 data.y
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'y'

# %%
data.y[]
# Out:
#   Cell In[15], line 1
#     data.y[]
#            ^
# SyntaxError: invalid syntax

# %%
data.y()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3560\2626246114.py in ?()
# ----> 1 data.y()
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'y'

# %%
plt.scatter(data['duration'],data['price'])

# %%
plt.scatter(data['duration','stops'],data['price'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('duration', 'stops')
#
# The above exception was the direct cause of the following exception:
# ...

# %%
plt.scatter(data['duration'],data['stops'])

# %%
train_data = pd.read_excel("flight dataset")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 train_data = pd.read_excel("flight dataset")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# --> 478     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479 elif engine and engine != io.engine:
#     480     raise ValueError(
#     481         "Engine should not be specified when passing "
# ...

# %%
train_data = pd.read_excel("C:\Users\R\Desktop\YEAR 3 NOTES\SEM 1\FINAL YEAR PROJECT\excel\flight dataset")
# Out:
#   Cell In[22], line 1
#     train_data = pd.read_excel("C:\Users\R\Desktop\YEAR 3 NOTES\SEM 1\FINAL YEAR PROJECT\excel\flight dataset")
#                                                                                                               ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
train_data = pd.read_excel("C:/Users/R/Desktop/YEAR 3 NOTES/SEM 1/FINAL YEAR PROJECT/excel/flight dataset.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 train_data = pd.read_excel("C:/Users/R/Desktop/YEAR 3 NOTES/SEM 1/FINAL YEAR PROJECT/excel/flight_dataset.xlsx")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# --> 478     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479 elif engine and engine != io.engine:
#     480     raise ValueError(
#     481         "Engine should not be specified when passing "
# ...

# %%
train_data = pd.read_excel("C:/Users/R/Desktop/YEAR 3 NOTES/SEM 1/FINAL YEAR PROJECT/excel/flight dataset.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\compat\_optional.py:142, in import_optional_dependency(name, extra, errors, min_version)
#     141 try:
# --> 142     module = importlib.import_module(name)
#     143 except ImportError:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1206, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1178, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1142, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# ...

# %%
train_data = pd.read_excel("C:/Users/R/Desktop/YEAR 3 NOTES/SEM 1/FINAL YEAR PROJECT/excel/flight dataset.xlsx")
# Out:
# C:\Users\R\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\reader\workbook.py:84: UserWarning: File contains an invalid specification for 0. This will be removed
#   warn(msg)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 train_data = pd.read_excel("C:/Users/R/Desktop/YEAR 3 NOTES/SEM 1/FINAL YEAR PROJECT/excel/flight dataset.xlsx")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:486, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     480     raise ValueError(
#     481         "Engine should not be specified when passing "
# ...

# %%
train_data = pd.read_excel("C:/Users/R/Desktop/YEAR 3 NOTES/SEM 1/FINAL YEAR PROJECT/excel/flight_dataset.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 train_data = pd.read_excel("C:/Users/R/Desktop/YEAR 3 NOTES/SEM 1/FINAL YEAR PROJECT/excel/flight_dataset.xlsx")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# --> 478     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479 elif engine and engine != io.engine:
#     480     raise ValueError(
#     481         "Engine should not be specified when passing "
# ...

# %%
train_data = pd.read_excel("C:/Users/R/Desktop/YEAR 3 NOTES/SEM 1/FINAL YEAR PROJECT/excel/flight dataset.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 train_data = pd.read_excel("C:/Users/R/Desktop/YEAR 3 NOTES/SEM 1/FINAL YEAR PROJECT/excel/flight dataset.xlsx")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:486, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     480     raise ValueError(
#     481         "Engine should not be specified when passing "
#     482         "an ExcelFile - ExcelFile already has the engine set"
#     483     )
#     485 try:
# --> 486     data = io.parse(
#     487         sheet_name=sheet_name,
# ...

# %%
   data = io.parse(
    487         sheet_name=sheet_name,
    488         header=header,
    489         names=names,
    490         index_col=index_col,
    491         usecols=usecols,
    492         dtype=dtype,
    493         converters=converters,
    494         true_values=true_values,
    495         false_values=false_values,
    496         skiprows=skiprows,
    497         nrows=nrows,
    498         na_values=na_values,
    499         keep_default_na=keep_default_na,
    500         na_filter=na_filter,
    501         verbose=verbose,
    502         parse_dates=parse_dates,
    503         date_parser=date_parser,
    504         date_format=date_format,
    505         thousands=thousands,
    506         decimal=decimal,
    507         comment=comment,
    508         skipfooter=skipfooter,
    509         dtype_backend=dtype_backend,
    510     )
# Out:
#   Cell In[31], line 2
#     487         sheet_name=sheet_name,
#     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
x = data[['from_airport_code', 'from_country', 'dest_airport_code' , 'dest_country', 'aircraft_type', 'airline_number', 'airline_name', 'flight_number', 'departure_time', 'arrival_time', 'duration', 'stops', 'co2_emissions', 'avg_co2_emission_for_this_route', 'co2_percentage', 'scan_date'
]]

y = data['price']

# %%
x
# Out:
#        from_airport_code from_country dest_airport_code dest_country
# 0                    ALG      Algeria               AEP    Argentina  \
# 1                    ALG      Algeria               AEP    Argentina
# 2                    ALG      Algeria               AEP    Argentina
# 3                    ALG      Algeria               AEP    Argentina
# 4                    ALG      Algeria               AEP    Argentina
# ...                  ...          ...               ...          ...
# 998861               BOM        India               SYD    Australia
# 998862               BOM        India               SYD    Australia
# 998863               BOM        India               SYD    Australia
# 998864               BOM        India               SYD    Australia
# 998865               BOM        India               SYD    Australia
#
#                                             aircraft_type airline_number
# ...

# %%
y
# Out:
# 0         1279.0
# 1         1279.0
# 2         1284.0
# 3         1290.0
# 4         1347.0
#            ...
# 998861    1317.0
# 998862    1317.0
# 998863    1328.0
# 998864    1368.0
# 998865    1368.0
# Name: price, Length: 998866, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2)

# %%
len(x_train)
# Out:
# 799092

# %%
len(x_test)
# Out:
# 199774

# %%
train_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 train_data.head()
#
# NameError: name 'train_data' is not defined

# %%
data.shape
# Out:
# (998866, 18)

# %%
data.dropna(inplace = True)

# %%
data.isnull().sum()
# Out:
# from_airport_code                  0
# from_country                       0
# dest_airport_code                  0
# dest_country                       0
# aircraft_type                      0
# airline_number                     0
# airline_name                       0
# flight_number                      0
# departure_time                     0
# arrival_time                       0
# duration                           0
# stops                              0
# price                              0
# currency                           0
# co2_emissions                      0
# avg_co2_emission_for_this_route    0
# co2_percentage                     0
# scan_date                          0
# dtype: int64

# %%
data.shape
# Out:
# (892539, 18)

# %%
 x_train
# Out:
#        from_airport_code from_country dest_airport_code    dest_country
# 377748               SCL        Chile               OSL          Norway  \
# 618548               DUB       Dublin               CDG          France
# 613657               DUB       Dublin               AEP       Argentina
# 775359               CDG       France               SIN       Singapore
# 375733               SCL        Chile               MCO   United States
# ...                  ...          ...               ...             ...
# 155238               VIE      Austria               AMS     Netherlands
# 631380               DUB       Dublin               LIS        Portugal
# 213642               BRU      Belgium               ARN          Sweden
# 652800               DUB       Dublin               LHR  United Kingdom
# 616511               CPH      Denmark               LGW  United Kingdom
#
#                                             aircraft_type airline_number
# ...

# %%
y_train
# Out:
# 377748    3342.0
# 618548     353.0
# 613657    2807.0
# 775359     828.0
# 375733     361.0
#            ...
# 155238     357.0
# 631380     234.0
# 213642     262.0
# 652800     131.0
# 616511    1260.0
# Name: price, Length: 799092, dtype: float64

# %%
x_train["scan_day"] = pd.to_datetime(x_train.scan_date, format = "%d/%m/%y /%Hr/%Min/%Sec").dt.day
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 x_train["scan_day"] = pd.to_datetime(x_train.scan_date, format = "%d/%m/%y /%Hr/%Min/%Sec").dt.day
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\tools\datetimes.py:1046, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1044             result = arg.tz_localize("utc")
#    1045 elif isinstance(arg, ABCSeries):
# -> 1046     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1047     if not cache_array.empty:
#    1048         result = arg.map(cache_array)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\tools\datetimes.py:250, in _maybe_cache(arg, format, cache, convert_listlike)
#     248 unique_dates = unique(arg)
# ...

# %%
data = pd.read_csv("C:/Users/R/Desktop/YEAR 3 NOTES/SEM 1/FINAL YEAR PROJECT/practicals/archive/flight data.csv")

# %%
data.head()
# Out:
#   from_airport_code from_country dest_airport_code dest_country
# 0               ALG      Algeria               AEP    Argentina  \
# 1               ALG      Algeria               AEP    Argentina
# 2               ALG      Algeria               AEP    Argentina
# 3               ALG      Algeria               AEP    Argentina
# 4               ALG      Algeria               AEP    Argentina
#
#                                        aircraft_type airline_number
# 0  Airbus A318|Canadair RJ 1000|Airbus A330|Airbu...          multi  \
# 1  Airbus A318|Canadair RJ 1000|Boeing 787|Airbus...          multi
# 2     Airbus A320|Airbus A321|Boeing 787|Airbus A320          multi
# 3     Airbus A318|Airbus A320|Boeing 787|Airbus A320          multi
# 4              Airbus A321neo|Boeing 777|Airbus A320          multi
#
#                   airline_name                flight_number   departure_time
# 0  [Air France| Iberia| LATAM]  AF1491|AF1491|AF1491|AF1491  4/30/2022 14:30  \
# ...

# %%
data = pd.read_excel("C:/Users/R/Desktop/YEAR 3 NOTES/SEM 1/FINAL YEAR PROJECT/practicals/archive/flight dataset.xlsl")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 data = pd.read_excel("C:/Users/R/Desktop/YEAR 3 NOTES/SEM 1/FINAL YEAR PROJECT/practicals/archive/flight dataset.xlsl")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# --> 478     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479 elif engine and engine != io.engine:
#     480     raise ValueError(
# ...

# %%
data = pd.read_excel("data = pd.read_excel("C:/Users/R/Desktop/YEAR 3 NOTES/SEM 1/FINAL YEAR PROJECT/practicals/archive/flight dataset.xlsl")
# Out:
#   Cell In[61], line 1
#     data = pd.read_excel("data = pd.read_excel("C:/Users/R/Desktop/YEAR 3 NOTES/SEM 1/FINAL YEAR PROJECT/practicals/archive/flight dataset.xlsl")
#                                                                                                                                                ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
data = pd.read_csv("C:/Users/R/Desktop/YEAR 3 NOTES/SEM 1/FINAL YEAR PROJECT/practicals/archive/flight data.csv")

# %%
data = pd.read_csv("C:/Users/R/Desktop/YEAR 3 NOTES/SEM 1/FINAL YEAR PROJECT/practicals/archive/flight data.csv")

# %%
data.head()
# Out:
#   from_airport_code from_country dest_airport_code dest_country
# 0               ALG      Algeria               AEP    Argentina  \
# 1               ALG      Algeria               AEP    Argentina
# 2               ALG      Algeria               AEP    Argentina
# 3               ALG      Algeria               AEP    Argentina
# 4               ALG      Algeria               AEP    Argentina
#
#                                        aircraft_type airline_number
# 0  Airbus A318|Canadair RJ 1000|Airbus A330|Airbu...          multi  \
# 1  Airbus A318|Canadair RJ 1000|Boeing 787|Airbus...          multi
# 2     Airbus A320|Airbus A321|Boeing 787|Airbus A320          multi
# 3     Airbus A318|Airbus A320|Boeing 787|Airbus A320          multi
# 4              Airbus A321neo|Boeing 777|Airbus A320          multi
#
#                   airline_name                flight_number   departure_time
# 0  [Air France| Iberia| LATAM]  AF1491|AF1491|AF1491|AF1491  4/30/2022 14:30  \
# ...

# %%
data = pd.read_csv("C:/Users/R/Desktop/YEAR 3 NOTES/SEM 1/FINAL YEAR PROJECT/practicals/archive/flight data.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data = pd.read_csv("C:/Users/R/Desktop/YEAR 3 NOTES/SEM 1/FINAL YEAR PROJECT/practicals/archive/flight data.csv")
#
# NameError: name 'pd' is not defined

# %%
data = pd.read_csv("C:/Users/R/Desktop/YEAR 3 NOTES/SEM 1/FINAL YEAR PROJECT/practicals/archive/flight data.csv")

# %%
data.head()
# Out:
#   from_airport_code from_country dest_airport_code dest_country
# 0               ALG      Algeria               AEP    Argentina  \
# 1               ALG      Algeria               AEP    Argentina
# 2               ALG      Algeria               AEP    Argentina
# 3               ALG      Algeria               AEP    Argentina
# 4               ALG      Algeria               AEP    Argentina
#
#                                        aircraft_type airline_number
# 0  Airbus A318|Canadair RJ 1000|Airbus A330|Airbu...          multi  \
# 1  Airbus A318|Canadair RJ 1000|Boeing 787|Airbus...          multi
# 2     Airbus A320|Airbus A321|Boeing 787|Airbus A320          multi
# 3     Airbus A318|Airbus A320|Boeing 787|Airbus A320          multi
# 4              Airbus A321neo|Boeing 777|Airbus A320          multi
#
#                   airline_name                flight_number
# 0  [Air France| Iberia| LATAM]  AF1491|AF1491|AF1491|AF1491  \
# ...

# %%
x = data[['from_airport_code', 'from_country', 'dest_airport_code' , 'dest_country', 'aircraft_type', 'airline_number', 'airline_name', 'flight_number', 'departure_time', 'arrival_time', 'duration', 'stops', 'co2_emissions', 'avg_co2_emission_for_this_route', 'co2_percentage', 'scan_date'
]]

y = data['price']

# %%
x
# Out:
#        from_airport_code from_country dest_airport_code dest_country
# 0                    ALG      Algeria               AEP    Argentina  \
# 1                    ALG      Algeria               AEP    Argentina
# 2                    ALG      Algeria               AEP    Argentina
# 3                    ALG      Algeria               AEP    Argentina
# 4                    ALG      Algeria               AEP    Argentina
# ...                  ...          ...               ...          ...
# 998861               BOM        India               SYD    Australia
# 998862               BOM        India               SYD    Australia
# 998863               BOM        India               SYD    Australia
# 998864               BOM        India               SYD    Australia
# 998865               BOM        India               SYD    Australia
#
#                                             aircraft_type airline_number
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2)

# %%
x_test
# Out:
#        from_airport_code from_country dest_airport_code   dest_country
# 395453               CAN        China               SYD      Australia  \
# 816405               FRA      Germany               CGK      Indonesia
# 465417               SHA        China               ORD  United States
# 869673               MUC      Germany               SFO  United States
# 464470               XIY        China               SHA          China
# ...                  ...          ...               ...            ...
# 47882                SYD    Australia               MUC        Germany
# 712160               CAI        Egypt               ZRH         Zurich
# 322400               YYZ       Canada               DEL          India
# 212691               BRU      Belgium               CPT   South Africa
# 103463               MEL    Australia               MEX         Mexico
#
#                                          aircraft_type airline_number
# ...

# %%
x_train
# Out:
#        from_airport_code from_country dest_airport_code          dest_country
# 989843               BOM        India               NBO                 Kenya  \
# 724990               CDG       France               GRU                Brazil
# 897558               ATH       Greece               MXP                 Italy
# 208574               BRU      Belgium               DXB  United Arab Emirates
# 912164               ATH       Greece               LIM                  Peru
# ...                  ...          ...               ...                   ...
# 433900               SZX        China               LAX         United States
# 327669               YYZ       Canada               BKK              Thailand
# 847435               MUC      Germany               LIS              Portugal
# 69147                SYD    Australia               DXB  United Arab Emirates
# 696477               CAI        Egypt               NRT                 Japan
#
# ...

# %%
x_train['arrival_time']
x_train['arrival_time'] = pd.to_datetime(x_train['arrival_time'])

# %%
x_train['Ahours'] = x_train['arrival_time'].dt.hour
x_train['Aminutes'] = x_train['arrival_time'].dt.minute
x_train['Aseconds'] = x_train['arrival_time'].dt.second

# %%
airline_name  = data[["airline_name"]]
airline_name = pd.get_dummies(airline_name, drop_first = True)
airline_name.head()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[7], line 2
#       1 airline_name  = data[["airline_name"]]
# ----> 2 airline_name = pd.get_dummies(airline_name, drop_first = True)
#       3 airline_name.head()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\encoding.py:213, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     203         dummy = _get_dummies_1d(
#     204             col[1],
#     205             prefix=pre,
#    (...)
#     210             dtype=dtype,
#     211         )
#     212         with_dummies.append(dummy)
# --> 213     result = concat(with_dummies, axis=1)
#     214 else:
#     215     result = _get_dummies_1d(
#     216         data,
#     217         prefix,
#    (...)
#     222         dtype=dtype,
#     223     )
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming your DataFrame is called 'data' and the airline name column is 'airline_name'
airline_encoder = LabelEncoder()
x_train['airline_name_encoded'] = airline_encoder.fit_transform(x_train['airline_name'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       3 # Assuming your DataFrame is called 'data' and the airline name column is 'airline_name'
#       4 airline_encoder = LabelEncoder()
# ----> 5 x_train['airline_name_encoded'] = airline_encoder.fit_transform(x_train['airline_name'])
#
# NameError: name 'x_train' is not defined
